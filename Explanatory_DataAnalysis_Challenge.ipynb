# %% [markdown]
# # Explanatory Data Analysis Challenge (Olympic Games)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Data Import and Inspection

# %% [markdown]
# Import the Datasets Summer (__summer.csv__), Winter (__winter.csv__) and dictionary (__dictionary.csv__) and Inspect!

# %%
summer = pd.read_csv('drive/MyDrive/Python - Pandas/Course_Materials_Part3/Explanatory_DataAnalysis_Challenge/summer.csv')
summer
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# [31165 rows x 9 columns]

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
winter = pd.read_csv('drive/MyDrive/Python - Pandas/Course_Materials_Part3/Explanatory_DataAnalysis_Challenge/winter.csv')
winter
# Out:
#       Year      City     Sport  ... Gender            Event   Medal
# 0     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 1     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 2     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 3     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 4     1924  Chamonix  Biathlon  ...    Men  Military Patrol    Gold
# ...    ...       ...       ...  ...    ...              ...     ...
# 5765  2014     Sochi    Skiing  ...  Women       Slopestyle  Bronze
# 5766  2014     Sochi    Skiing  ...  Women       Slopestyle    Gold
# 5767  2014     Sochi    Skiing  ...  Women  Snowboard Cross  Silver
# 5768  2014     Sochi    Skiing  ...  Women  Snowboard Cross    Gold
# 5769  2014     Sochi    Skiing  ...  Women  Snowboard Cross  Bronze
#
# [5770 rows x 9 columns]

# %%
winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770 entries, 0 to 5769
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        5770 non-null   int64
#  1   City        5770 non-null   object
#  2   Sport       5770 non-null   object
#  3   Discipline  5770 non-null   object
#  4   Athlete     5770 non-null   object
#  5   Country     5770 non-null   object
#  6   Gender      5770 non-null   object
#  7   Event       5770 non-null   object
#  8   Medal       5770 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 405.8+ KB

# %%
dictionary = pd.read_csv('drive/MyDrive/Python - Pandas/Course_Materials_Part3/Explanatory_DataAnalysis_Challenge/dictionary.csv')
dictionary
# Out:
#              Country Code  Population  GDP per Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %%
dictionary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         201 non-null    object
#  1   Code            201 non-null    object
#  2   Population      196 non-null    float64
#  3   GDP per Capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# ## Merging and Concatenating

# %% [markdown]
# 1. __Merge__ Summer and Winter (one row for each Medal awarded in any Olympic Games) and save the merged DataFrame in __olympics__.
# 2. An __additional column__ (e.g. "Edition") shall indicate the Edition -> __Summer or Winter__.
# 3. Add the __full Country name__ from dictionary to olympics (e.g. France for FRA).

# %%
summer['Edition'] = 'Summer'
summer.head()
# Out:
#    Year    City     Sport  ...                       Event   Medal Edition
# 0  1896  Athens  Aquatics  ...              100M Freestyle    Gold  Summer
# 1  1896  Athens  Aquatics  ...              100M Freestyle  Silver  Summer
# 2  1896  Athens  Aquatics  ...  100M Freestyle For Sailors  Bronze  Summer
# 3  1896  Athens  Aquatics  ...  100M Freestyle For Sailors    Gold  Summer
# 4  1896  Athens  Aquatics  ...  100M Freestyle For Sailors  Silver  Summer
#
# [5 rows x 10 columns]

# %%
winter['Edition'] = 'Winter'
winter.head()
# Out:
#    Year      City     Sport Discipline  ... Gender            Event   Medal Edition
# 0  1924  Chamonix  Biathlon   Biathlon  ...    Men  Military Patrol  Bronze  Winter
# 1  1924  Chamonix  Biathlon   Biathlon  ...    Men  Military Patrol  Bronze  Winter
# 2  1924  Chamonix  Biathlon   Biathlon  ...    Men  Military Patrol  Bronze  Winter
# 3  1924  Chamonix  Biathlon   Biathlon  ...    Men  Military Patrol  Bronze  Winter
# 4  1924  Chamonix  Biathlon   Biathlon  ...    Men  Military Patrol    Gold  Winter
#
# [5 rows x 10 columns]

# %%
olympics = pd.concat([summer,winter], ignore_index=True)
olympics
# Out:
#        Year    City     Sport  ...                       Event   Medal Edition
# 0      1896  Athens  Aquatics  ...              100M Freestyle    Gold  Summer
# 1      1896  Athens  Aquatics  ...              100M Freestyle  Silver  Summer
# 2      1896  Athens  Aquatics  ...  100M Freestyle For Sailors  Bronze  Summer
# 3      1896  Athens  Aquatics  ...  100M Freestyle For Sailors    Gold  Summer
# 4      1896  Athens  Aquatics  ...  100M Freestyle For Sailors  Silver  Summer
# ...     ...     ...       ...  ...                         ...     ...     ...
# 36930  2014   Sochi    Skiing  ...                  Slopestyle  Bronze  Winter
# 36931  2014   Sochi    Skiing  ...                  Slopestyle    Gold  Winter
# 36932  2014   Sochi    Skiing  ...             Snowboard Cross  Silver  Winter
# 36933  2014   Sochi    Skiing  ...             Snowboard Cross    Gold  Winter
# 36934  2014   Sochi    Skiing  ...             Snowboard Cross  Bronze  Winter
#
# [36935 rows x 10 columns]

# %%
names = {'URS': 'Soviet Union',
 'GDR': 'East Germany',
 'ROU': 'Romania',
 'FRG': 'West Germany',
 'TCH': 'Czechoslovakia',
 'YUG': 'Yugoslavia',
 'EUN': 'Unified Team',
 'EUA': 'Unified Team of Germany',
 'ZZX': 'Mixed teams',
 'SRB': 'Serbia',
 'ANZ': 'Australasia',
 'RU1': 'Russian Empire',
 'MNE': 'Montenegro',
 'TTO': 'Trinidad and Tobago',
 'BOH': 'Bohemia',
 'BWI': 'West Indies Federation',
 'SGP': 'Singapore',
 'IOP': 'Independent Olympic Participants'}

# %%
olympics = olympics.merge(dictionary.iloc[:, :2], how = "left", 
               left_on = "Country", right_on = "Code").drop(columns = ["Code"])
olympics
# Out:
#        Year    City     Sport  ...   Medal Edition       Country_y
# 0      1896  Athens  Aquatics  ...    Gold  Summer         Hungary
# 1      1896  Athens  Aquatics  ...  Silver  Summer         Austria
# 2      1896  Athens  Aquatics  ...  Bronze  Summer          Greece
# 3      1896  Athens  Aquatics  ...    Gold  Summer          Greece
# 4      1896  Athens  Aquatics  ...  Silver  Summer          Greece
# ...     ...     ...       ...  ...     ...     ...             ...
# 36930  2014   Sochi    Skiing  ...  Bronze  Winter  United Kingdom
# 36931  2014   Sochi    Skiing  ...    Gold  Winter   United States
# 36932  2014   Sochi    Skiing  ...  Silver  Winter          Canada
# 36933  2014   Sochi    Skiing  ...    Gold  Winter  Czech Republic
# 36934  2014   Sochi    Skiing  ...  Bronze  Winter          France
#
# [36935 rows x 11 columns]

# %% [markdown]
# ## Data Cleaning (Part 1)

# %% [markdown]
# 1. If you haven´t done it yet: Assign appropriate __Column Headers__ to Country Codes (e.g. __"Code"__) and full Country Names (e.g. __"Country"__).
# 2. __Remove Spaces__ from column headers in olympics and dictionary.
# 3. For some Country Codes, there is no corresponding __full Country Name__ available (e.g. for "URS") -> __missing values__ in olympics. Identify these Country Codes and search the Web for the full Country Names. __Replace__ missing values! (Alternatively, you can find a Solution for this at the end of this Notebook!)

# %%
olympics.rename(columns={'Country_x': 'Code', 'Country_y':'Country'}, inplace=True)
olympics
# Out:
#        Year    City     Sport  ...   Medal Edition         Country
# 0      1896  Athens  Aquatics  ...    Gold  Summer         Hungary
# 1      1896  Athens  Aquatics  ...  Silver  Summer         Austria
# 2      1896  Athens  Aquatics  ...  Bronze  Summer          Greece
# 3      1896  Athens  Aquatics  ...    Gold  Summer          Greece
# 4      1896  Athens  Aquatics  ...  Silver  Summer          Greece
# ...     ...     ...       ...  ...     ...     ...             ...
# 36930  2014   Sochi    Skiing  ...  Bronze  Winter  United Kingdom
# 36931  2014   Sochi    Skiing  ...    Gold  Winter   United States
# 36932  2014   Sochi    Skiing  ...  Silver  Winter          Canada
# 36933  2014   Sochi    Skiing  ...    Gold  Winter  Czech Republic
# 36934  2014   Sochi    Skiing  ...  Bronze  Winter          France
#
# [36935 rows x 11 columns]

# %%
olympics.columns = olympics.columns.str.replace(' ', '') 
olympics
# Out:
#        Year    City     Sport  ...   Medal Edition         Country
# 0      1896  Athens  Aquatics  ...    Gold  Summer         Hungary
# 1      1896  Athens  Aquatics  ...  Silver  Summer         Austria
# 2      1896  Athens  Aquatics  ...  Bronze  Summer          Greece
# 3      1896  Athens  Aquatics  ...    Gold  Summer          Greece
# 4      1896  Athens  Aquatics  ...  Silver  Summer          Greece
# ...     ...     ...       ...  ...     ...     ...             ...
# 36930  2014   Sochi    Skiing  ...  Bronze  Winter  United Kingdom
# 36931  2014   Sochi    Skiing  ...    Gold  Winter   United States
# 36932  2014   Sochi    Skiing  ...  Silver  Winter          Canada
# 36933  2014   Sochi    Skiing  ...    Gold  Winter  Czech Republic
# 36934  2014   Sochi    Skiing  ...  Bronze  Winter          France
#
# [36935 rows x 11 columns]

# %%
dictionary.columns = dictionary.columns.str.replace(' ', '_') 
dictionary
# Out:
#              Country Code  Population  GDP_per_Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %%
olympics[olympics.Country.isna()]
# Out:
#        Year         City   Sport  ...   Medal Edition Country
# 132    1896       Athens  Tennis  ...  Bronze  Summer     NaN
# 133    1896       Athens  Tennis  ...  Bronze  Summer     NaN
# 134    1896       Athens  Tennis  ...    Gold  Summer     NaN
# 135    1896       Athens  Tennis  ...    Gold  Summer     NaN
# 136    1896       Athens  Tennis  ...  Silver  Summer     NaN
# ...     ...          ...     ...  ...     ...     ...     ...
# 33961  1992  Albertville  Skiing  ...  Silver  Winter     NaN
# 33977  1992  Albertville  Skiing  ...  Bronze  Winter     NaN
# 33978  1992  Albertville  Skiing  ...  Bronze  Winter     NaN
# 33979  1992  Albertville  Skiing  ...  Bronze  Winter     NaN
# 33980  1992  Albertville  Skiing  ...  Bronze  Winter     NaN
#
# [6367 rows x 11 columns]

# %%
olympics.Country = olympics.Country.fillna(olympics.Code.map(names))
olympics.loc[33980,'Country']
# Out:
# 'Czechoslovakia'

# %%
olympics[olympics.Country.isna()]
# Out:
#        Year    City          Sport  ...   Medal Edition Country
# 29603  2012  London      Athletics  ...    Gold  Summer     NaN
# 31072  2012  London  Weightlifting  ...    Gold  Summer     NaN
# 31091  2012  London  Weightlifting  ...  Silver  Summer     NaN
# 31110  2012  London      Wrestling  ...  Silver  Summer     NaN
#
# [4 rows x 11 columns]

# %% [markdown]
# ## Data Cleaning (Part 2)

# %% [markdown]
# 1. __Remove rows__ from olympics where the Country code is unknown. (Make sure you reset the Index -> RangeIndex)
# 2. Convert the column __Medal__ into an __ordered Categorical__ column ("Bronze" < "Silver" < "Gold")

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36935 entries, 0 to 36934
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        36935 non-null  int64
#  1   City        36935 non-null  object
#  2   Sport       36935 non-null  object
#  3   Discipline  36935 non-null  object
#  4   Athlete     36935 non-null  object
#  5   Code        36931 non-null  object
#  6   Gender      36935 non-null  object
#  7   Event       36935 non-null  object
#  8   Medal       36935 non-null  object
#  9   Edition     36935 non-null  object
#  10  Country     36931 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.6+ MB

# %%
olympics.dropna(inplace=True)
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36931 entries, 0 to 36934
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        36931 non-null  int64
#  1   City        36931 non-null  object
#  2   Sport       36931 non-null  object
#  3   Discipline  36931 non-null  object
#  4   Athlete     36931 non-null  object
#  5   Code        36931 non-null  object
#  6   Gender      36931 non-null  object
#  7   Event       36931 non-null  object
#  8   Medal       36931 non-null  object
#  9   Edition     36931 non-null  object
#  10  Country     36931 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 3.4+ MB

# %%
olympics.reset_index(inplace=True)

# %%
medal_ordering = ["Gold","Silver","Bronze"]

# %%
olympics.Medal = pd.Categorical(olympics.Medal, categories=medal_ordering, ordered=True)
olympics
# Out:
#        index  Year    City  ...   Medal Edition         Country
# 0          0  1896  Athens  ...    Gold  Summer         Hungary
# 1          1  1896  Athens  ...  Silver  Summer         Austria
# 2          2  1896  Athens  ...  Bronze  Summer          Greece
# 3          3  1896  Athens  ...    Gold  Summer          Greece
# 4          4  1896  Athens  ...  Silver  Summer          Greece
# ...      ...   ...     ...  ...     ...     ...             ...
# 36926  36930  2014   Sochi  ...  Bronze  Winter  United Kingdom
# 36927  36931  2014   Sochi  ...    Gold  Winter   United States
# 36928  36932  2014   Sochi  ...  Silver  Winter          Canada
# 36929  36933  2014   Sochi  ...    Gold  Winter  Czech Republic
# 36930  36934  2014   Sochi  ...  Bronze  Winter          France
#
# [36931 rows x 12 columns]

# %% [markdown]
# ## What are the most successful countries of all times?

# %% [markdown]
# For the next questions, use Seaborn plots.
# 1. What are the __Top 10__ Countries by __total medals__?
# 2. __Split__ the total medals of Top 10 Countries into __Summer / Winter__. Are there typical Summer/Winter Games Countries?
# 3. __Split__ the total medals of Top 10 Countries into __Gold, Silver, Bronze__.

# %%
olympics.groupby('Medal').Country.value_counts()
# Out:
# Medal   Country
# Gold    United States     2402
#         Soviet Union      1088
#         Germany            589
#         United Kingdom     580
#         Italy              534
#                           ...
# Bronze  Suriname             1
#         Syria                1
#         Togo                 1
#         Zambia               1
#         Zimbabwe             1
# Name: Country, Length: 346, dtype: int64

# %%
top_10 = olympics.Country.value_counts().head(10)
top_10
# Out:
# United States     5238
# Soviet Union      2489
# United Kingdom    1799
# Germany           1665
# France            1548
# Italy             1488
# Sweden            1477
# Canada            1274
# Australia         1204
# Hungary           1091
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,10))
top_10.plot(kind = 'bar')

# %%
olympics_summer = olympics.loc[olympics.Edition=='Summer']

# %%
top_10_summer = olympics_summer.Country.value_counts().head(10)
top_10_summer
# Out:
# United States     4585
# Soviet Union      2049
# United Kingdom    1720
# France            1396
# Germany           1305
# Italy             1296
# Australia         1189
# Hungary           1079
# Sweden            1044
# Netherlands        851
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,10))
top_10_summer.plot(kind = 'bar')

# %%
olympics_winter = olympics.loc[olympics.Edition=='Winter']

# %%
top_10_winter = olympics_winter.Country.value_counts().head(10)
top_10_winter
# Out:
# United States    653
# Canada           625
# Norway           457
# Soviet Union     440
# Finland          434
# Sweden           433
# Germany          360
# Switzerland      285
# Austria          280
# Russia           263
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,10))
top_10_winter.plot(kind = 'bar')

# %% [markdown]
# ## Do GDP, Population and Politics matter?

# %% [markdown]
# 1. Create the following __aggregated and merged__ DataFrame with __Top 50 Countries__ (you can see an excerpt with the first 12 Countries). The Column __Total_Games__ shows the __number of Participations__ (as an approximation: determine the number of Editions where Countries have won at least one medal).

# %%
dictionary.head()
# Out:
#            Country Code  Population  GDP_per_Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
top_50 = olympics.Country.value_counts().head(50)
top_50.shape
# Out:
# (50,)

# %%
dictionary.shape
# Out:
# (201, 4)

# %%
top_country = olympics.groupby('Country').Medal.count().sort_values(ascending = False).head(50)
top_country
# Out:
# Country
# United States              5238
# Soviet Union               2489
# United Kingdom             1799
# Germany                    1665
# France                     1548
# Italy                      1488
# Sweden                     1477
# Canada                     1274
# Australia                  1204
# Hungary                    1091
# Russia                     1031
# Norway                     1011
# East Germany                987
# Netherlands                 973
# Finland                     890
# China                       889
# Japan                       851
# Switzerland                 665
# Romania                     642
# Korea, South                616
# West Germany                584
# Poland                      538
# Denmark                     512
# Czechoslovakia              487
# Spain                       444
# Yugoslavia                  442
# Brazil                      431
# Austria                     426
# Belgium                     424
# Cuba                        410
# Bulgaria                    339
# Unified Team                283
# Unified Team of Germany     281
# Argentina                   259
# New Zealand                 191
# Ukraine                     184
# India                       184
# Greece                      148
# Czech Republic              131
# Belarus                     128
# Jamaica                     127
# Croatia                     125
# Pakistan                    121
# South Africa                106
# Mexico                      106
# Kenya                        93
# Turkey                       86
# Nigeria                      84
# Uruguay                      76
# Iran                         61
# Name: Medal, dtype: int64

# %%
top_country.rename('Total', inplace=True)
# Out:
# Country
# United States              5238
# Soviet Union               2489
# United Kingdom             1799
# Germany                    1665
# France                     1548
# Italy                      1488
# Sweden                     1477
# Canada                     1274
# Australia                  1204
# Hungary                    1091
# Russia                     1031
# Norway                     1011
# East Germany                987
# Netherlands                 973
# Finland                     890
# China                       889
# Japan                       851
# Switzerland                 665
# Romania                     642
# Korea, South                616
# West Germany                584
# Poland                      538
# Denmark                     512
# Czechoslovakia              487
# Spain                       444
# Yugoslavia                  442
# Brazil                      431
# Austria                     426
# Belgium                     424
# Cuba                        410
# Bulgaria                    339
# Unified Team                283
# Unified Team of Germany     281
# Argentina                   259
# New Zealand                 191
# Ukraine                     184
# India                       184
# Greece                      148
# Czech Republic              131
# Belarus                     128
# Jamaica                     127
# Croatia                     125
# Pakistan                    121
# South Africa                106
# Mexico                      106
# Kenya                        93
# Turkey                       86
# Nigeria                      84
# Uruguay                      76
# Iran                         61
# Name: Total, dtype: int64

# %%
top_medal = olympics.groupby('Country').Medal.value_counts().unstack().fillna(0)
top_medal
# Out:
# Medal                    Gold  Silver  Bronze
# Country
# Afghanistan               0.0     0.0     2.0
# Algeria                   5.0     2.0     8.0
# Argentina                69.0    99.0    91.0
# Armenia                   1.0     2.0     8.0
# Australasia              20.0     4.0     5.0
# ...                       ...     ...     ...
# West Germany            166.0   191.0   227.0
# West Indies Federation    0.0     0.0     5.0
# Yugoslavia              143.0   180.0   119.0
# Zambia                    0.0     1.0     1.0
# Zimbabwe                 18.0     4.0     1.0
#
# [145 rows x 3 columns]

# %%
top_medal.sort_values(by="Gold", ascending=False, inplace=True)

# %%
top_medal.Gold = top_medal.Gold.astype('Int32')
top_medal.Silver = top_medal.Silver.astype('Int32')
top_medal.Bronze = top_medal.Bronze.astype('Int32')

# %%
top_medal
# Out:
# Medal           Gold  Silver  Bronze
# Country
# United States   2402    1571    1265
# Soviet Union    1088     724     677
# Germany          589     504     572
# United Kingdom   580     632     587
# Italy            534     473     481
# ...              ...     ...     ...
# Iceland            0      15       2
# Haiti              0       1       7
# Guyana             0       0       1
# Moldova            0       3       3
# Afghanistan        0       0       2
#
# [145 rows x 3 columns]

# %%
total = top_medal.sum(axis = 1).astype('Int32')
total.repl
# Out:
# Country
# United States     5238
# Soviet Union      2489
# Germany           1665
# United Kingdom    1799
# Italy             1488
#                   ...
# Iceland             17
# Haiti                8
# Guyana               1
# Moldova              6
# Afghanistan          2
# Length: 145, dtype: Int32

# %%
medals_per_country = pd.crosstab(index = olympics.Country, columns = olympics.Medal, 
                                 margins = True, margins_name= "Total")
medals_per_country
# Out:
# Medal                    Gold  Silver  Bronze  Total
# Country
# Afghanistan                 0       0       2      2
# Algeria                     5       2       8     15
# Argentina                  69      99      91    259
# Armenia                     1       2       8     11
# Australasia                20       4       5     29
# ...                       ...     ...     ...    ...
# West Indies Federation      0       0       5      5
# Yugoslavia                143     180     119    442
# Zambia                      0       1       1      2
# Zimbabwe                   18       4       1     23
# Total                   12405   12238   12288  36931
#
# [146 rows x 4 columns]

# %%
medals_per_country.drop("Total", axis = 0, inplace = True)

# %%
medals_per_country = medals_per_country[["Total", "Gold", "Silver", "Bronze"]].sort_values(by = ["Total", "Gold", "Silver", "Bronze"], ascending = False)
medals_per_country
# Out:
# Medal           Total  Gold  Silver  Bronze
# Country
# United States    5238  2402    1571    1265
# Soviet Union     2489  1088     724     677
# United Kingdom   1799   580     632     587
# Germany          1665   589     504     572
# France           1548   444     526     578
# ...               ...   ...     ...     ...
# Iraq                1     0       0       1
# Macedonia           1     0       0       1
# Mauritius           1     0       0       1
# Niger               1     0       0       1
# Togo                1     0       0       1
#
# [145 rows x 4 columns]

# %%
medals_per_country = medals_per_country.merge(dictionary, how = "left", left_index = True, 
                                              right_on = "Country").drop(columns = ["Code"]).set_index("Country")

# %%
medals_per_country
# Out:
#                 Total  Gold  Silver  Bronze   Population  GDP_per_Capita
# Country
# United States    5238  2402    1571    1265  321418820.0    56115.718426
# Soviet Union     2489  1088     724     677          NaN             NaN
# United Kingdom   1799   580     632     587   65138232.0    43875.969614
# Germany          1665   589     504     572   81413145.0    41313.313995
# France           1548   444     526     578   66808385.0    36205.568102
# ...               ...   ...     ...     ...          ...             ...
# Iraq                1     0       0       1   36423395.0     4943.760388
# Macedonia           1     0       0       1    2078453.0     4852.657848
# Mauritius           1     0       0       1    1262605.0     9252.110724
# Niger               1     0       0       1   19899120.0      358.958152
# Togo                1     0       0       1    7304578.0      559.635877
#
# [145 rows x 6 columns]

# %%
olympics["Games"] = olympics.apply(lambda x: str(x.Year) + " " + x.City, axis = 1)

# %%
olympics
# Out:
#        index  Year    City  ... Edition         Country        Games
# 0          0  1896  Athens  ...  Summer         Hungary  1896 Athens
# 1          1  1896  Athens  ...  Summer         Austria  1896 Athens
# 2          2  1896  Athens  ...  Summer          Greece  1896 Athens
# 3          3  1896  Athens  ...  Summer          Greece  1896 Athens
# 4          4  1896  Athens  ...  Summer          Greece  1896 Athens
# ...      ...   ...     ...  ...     ...             ...          ...
# 36926  36930  2014   Sochi  ...  Winter  United Kingdom   2014 Sochi
# 36927  36931  2014   Sochi  ...  Winter   United States   2014 Sochi
# 36928  36932  2014   Sochi  ...  Winter          Canada   2014 Sochi
# 36929  36933  2014   Sochi  ...  Winter  Czech Republic   2014 Sochi
# 36930  36934  2014   Sochi  ...  Winter          France   2014 Sochi
#
# [36931 rows x 13 columns]

# %%
olympics.Games.nunique()
# Out:
# 49

# %%
olympics.groupby("Country").apply(lambda x: x.Games.nunique())
# Out:
# Country
# Afghanistan                2
# Algeria                    6
# Argentina                 18
# Armenia                    4
# Australasia                2
#                           ..
# West Germany              12
# West Indies Federation     1
# Yugoslavia                18
# Zambia                     2
# Zimbabwe                   3
# Length: 145, dtype: int64

# %%
medals_per_country["Total_Games"] = olympics.groupby("Country").apply(lambda x: x.Games.nunique())

# %%
medals_per_country
# Out:
#                 Total  Gold  Silver  ...   Population  GDP_per_Capita  Total_Games
# Country                              ...
# United States    5238  2402    1571  ...  321418820.0    56115.718426           48
# Soviet Union     2489  1088     724  ...          NaN             NaN           18
# United Kingdom   1799   580     632  ...   65138232.0    43875.969614           42
# Germany          1665   589     504  ...   81413145.0    41313.313995           25
# France           1548   444     526  ...   66808385.0    36205.568102           47
# ...               ...   ...     ...  ...          ...             ...          ...
# Iraq                1     0       0  ...   36423395.0     4943.760388            1
# Macedonia           1     0       0  ...    2078453.0     4852.657848            1
# Mauritius           1     0       0  ...    1262605.0     9252.110724            1
# Niger               1     0       0  ...   19899120.0      358.958152            1
# Togo                1     0       0  ...    7304578.0      559.635877            1
#
# [145 rows x 7 columns]

# %%
medals_per_country.rank(ascending = False).head(50)
# Out:
#                          Total  Gold  ...  GDP_per_Capita  Total_Games
# Country                               ...
# United States              1.0   1.0  ...             7.0          1.0
# Soviet Union               2.0   2.0  ...             NaN         28.0
# United Kingdom             3.0   4.0  ...            13.0         10.0
# Germany                    4.0   3.0  ...            18.0         19.0
# France                     5.0   8.0  ...            22.0          3.0
# Italy                      6.0   5.0  ...            25.0          9.0
# Sweden                     7.0   6.0  ...            10.0          3.0
# Canada                     8.0   7.0  ...            15.0          3.0
# Australia                  9.0  13.0  ...             6.0         14.0
# Hungary                   10.0   9.0  ...            48.0         13.0
# Russia                    11.0  12.0  ...            57.0         45.0
# Norway                    12.0  11.0  ...             3.0          8.0
# East Germany              13.0  10.0  ...             NaN         45.0
# Netherlands               14.0  15.0  ...            12.0         11.0
# Finland                   15.0  18.0  ...            17.0          6.0
# China                     16.0  14.0  ...            63.0         34.5
# Japan                     17.0  16.0  ...            24.0         12.0
# Switzerland               18.0  22.0  ...             2.0          6.0
# Romania                   19.0  21.0  ...            59.0         24.0
# Korea, South              20.0  17.0  ...            27.0         20.0
# West Germany              21.0  19.0  ...             NaN         40.0
# Poland                    22.0  27.0  ...            47.0         17.0
# Denmark                   23.0  23.0  ...             9.0         17.0
# Czechoslovakia            24.0  32.0  ...             NaN         17.0
# Spain                     25.0  29.0  ...            28.0         22.0
# Yugoslavia                26.0  24.0  ...             NaN         28.0
# Brazil                    27.0  34.0  ...            60.0         28.0
# Austria                   28.0  28.0  ...            14.0          6.0
# Belgium                   29.0  30.0  ...            20.0         15.0
# Cuba                      30.0  20.0  ...             NaN         36.5
# Bulgaria                  31.0  36.0  ...            64.0         24.0
# Unified Team              32.0  25.5  ...             NaN        107.5
# Unified Team of Germany   33.0  33.0  ...             NaN         73.0
# Argentina                 34.0  35.0  ...            44.0         28.0
# New Zealand               35.0  31.0  ...            21.0         21.0
# India                     36.5  25.5  ...           100.0         31.5
# Ukraine                   36.5  38.0  ...            96.0         57.0
# Greece                    38.0  43.0  ...            35.0         28.0
# Czech Republic            39.0  40.5  ...            36.0         50.5
# Belarus                   40.0  48.5  ...            71.0         45.0
# Jamaica                   41.0  45.0  ...            75.0         36.5
# Croatia                   42.0  37.0  ...            49.0         50.5
# Pakistan                  43.0  40.5  ...           101.0         57.0
# Mexico                    44.5  44.0  ...            58.0         24.0
# South Africa              44.5  46.0  ...            72.0         31.5
# Kenya                     46.0  47.0  ...           103.0         45.0
# Turkey                    47.0  42.0  ...            56.0         33.0
# Nigeria                   48.0  53.0  ...            93.0         64.0
# Uruguay                   49.0  39.0  ...            40.0         64.0
# Iran                      50.0  55.0  ...             NaN         34.5
#
# [50 rows x 7 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Statistical Analysis and Hypothesis Testing with scipy

# %% [markdown]
# In the follwing work with __Ranks__!
# Check whether __GDP__ (Standard of Living), __Total_Games__ (Political Stability measure) and __Population__ (Size) have an effect on __Total Medals__. (hint: work with spearman correlation, not with pearson correlation)

# %%
import scipy.stats as stats

# %%
medals_per_country.drop(columns=['Gold', 'Silver', 'Bronze']).corr('pearson')
# Out:
#                    Total  Population  GDP_per_Capita  Total_Games
# Total           1.000000    0.206606        0.437131     0.712917
# Population      0.206606    1.000000       -0.089976     0.123700
# GDP_per_Capita  0.437131   -0.089976        1.000000     0.563540
# Total_Games     0.712917    0.123700        0.563540     1.000000

# %%
medals_per_country.drop(columns=['Gold', 'Silver', 'Bronze']).rank(ascending = False).corr('spearman')
# Out:
#                    Total  Population  GDP_per_Capita  Total_Games
# Total           1.000000    0.419755        0.458478     0.927611
# Population      0.419755    1.000000       -0.239097     0.402098
# GDP_per_Capita  0.458478   -0.239097        1.000000     0.498056
# Total_Games     0.927611    0.402098        0.498056     1.000000

# %%
stats.spearmanr(medals_per_country.Total, medals_per_country.Population, 
                             nan_policy = "omit")
# Out:
# SpearmanrResult(correlation=0.41975527887063924, pvalue=8.132240868116897e-07)

# %%
r, p_value = stats.spearmanr(medals_per_country.Total, medals_per_country.Population, 
                             nan_policy = "omit")

# %%
r
# Out:
# 0.41975527887063924

# %%
round(p_value)
# Out:
# 0

# %%
stats.spearmanr(medals_per_country.Total, medals_per_country.GDP_per_Capita, 
                             nan_policy = "omit")
# Out:
# SpearmanrResult(correlation=0.45847787983426685, pvalue=1.5758169913239602e-07)

# %%
r1, p_value1 = stats.spearmanr(medals_per_country.Total, medals_per_country.GDP_per_Capita, 
                             nan_policy = "omit")
print(r1)
print(p_value1)
# Out:
# 0.45847787983426685
# 1.5758169913239602e-07

# %%
stats.spearmanr(medals_per_country.Total, medals_per_country.Total_Games, 
                             nan_policy = "omit")
# Out:
# SpearmanrResult(correlation=0.9276106841243015, pvalue=5.026540188200113e-63)

# %%
r2, p_value2 = stats.spearmanr(medals_per_country.Total, medals_per_country.Total_Games, 
                             nan_policy = "omit")
print(r2)
print(p_value2)
# Out:
# 0.9276106841243015
# 5.026540188200113e-63

# %% [markdown]
# ## Aggregating and Ranking

# %% [markdown]
# Create the following __Seaborn Heatmap__ with __Medal Ranks__ for Top 50 Countries (Total Medals, Summer Games Medals, Winter Games Medals, Men, Women).

# %%
olympics
# Out:
#        index  Year    City  ... Edition         Country        Games
# 0          0  1896  Athens  ...  Summer         Hungary  1896 Athens
# 1          1  1896  Athens  ...  Summer         Austria  1896 Athens
# 2          2  1896  Athens  ...  Summer          Greece  1896 Athens
# 3          3  1896  Athens  ...  Summer          Greece  1896 Athens
# 4          4  1896  Athens  ...  Summer          Greece  1896 Athens
# ...      ...   ...     ...  ...     ...             ...          ...
# 36926  36930  2014   Sochi  ...  Winter  United Kingdom   2014 Sochi
# 36927  36931  2014   Sochi  ...  Winter   United States   2014 Sochi
# 36928  36932  2014   Sochi  ...  Winter          Canada   2014 Sochi
# 36929  36933  2014   Sochi  ...  Winter  Czech Republic   2014 Sochi
# 36930  36934  2014   Sochi  ...  Winter          France   2014 Sochi
#
# [36931 rows x 13 columns]

# %%
sum_vs_win = pd.crosstab(olympics.Country, olympics.Edition)
sum_vs_win
# Out:
# Edition                 Summer  Winter
# Country
# Afghanistan                  2       0
# Algeria                     15       0
# Argentina                  259       0
# Armenia                     11       0
# Australasia                 29       0
# ...                        ...     ...
# West Germany               490      94
# West Indies Federation       5       0
# Yugoslavia                 435       7
# Zambia                       2       0
# Zimbabwe                    23       0
#
# [145 rows x 2 columns]

# %%
men_vs_woman = pd.crosstab(olympics.Country, olympics.Gender)
men_vs_woman
# Out:
# Gender                  Men  Women
# Country
# Afghanistan               2      0
# Algeria                  12      3
# Argentina               187     72
# Armenia                  11      0
# Australasia              27      2
# ...                     ...    ...
# West Germany            450    134
# West Indies Federation    5      0
# Yugoslavia              379     63
# Zambia                    2      0
# Zimbabwe                  0     23
#
# [145 rows x 2 columns]

# %%
gender_season = pd.concat([sum_vs_win, men_vs_woman], axis = 1)
gender_season
# Out:
#                         Summer  Winter  Men  Women
# Country
# Afghanistan                  2       0    2      0
# Algeria                     15       0   12      3
# Argentina                  259       0  187     72
# Armenia                     11       0   11      0
# Australasia                 29       0   27      2
# ...                        ...     ...  ...    ...
# West Germany               490      94  450    134
# West Indies Federation       5       0    5      0
# Yugoslavia                 435       7  379     63
# Zambia                       2       0    2      0
# Zimbabwe                    23       0    0     23
#
# [145 rows x 4 columns]

# %%
gender_season['Total'] = gender_season.Summer.add(gender_season.Winter)
gender_season
# Out:
#                         Summer  Winter  Men  Women  Total
# Country
# Afghanistan                  2       0    2      0      2
# Algeria                     15       0   12      3     15
# Argentina                  259       0  187     72    259
# Armenia                     11       0   11      0     11
# Australasia                 29       0   27      2     29
# ...                        ...     ...  ...    ...    ...
# West Germany               490      94  450    134    584
# West Indies Federation       5       0    5      0      5
# Yugoslavia                 435       7  379     63    442
# Zambia                       2       0    2      0      2
# Zimbabwe                    23       0    0     23     23
#
# [145 rows x 5 columns]

# %%
gender_season.sort_values(by='Total', ascending=False, inplace=True)

# %%
plt.figure(figsize=(50,10))
sns.heatmap(gender_season.rank().head(20).T, annot=True, cmap='RdYlGn_r', fmt='2.0f')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Summer Games vs. Winter Games - does Geographical Location matter?

# %% [markdown]
# [Текст ссылки](https://)__Identify Countries__ that are
# 1. __equally successful__ in Summer and Winter Games
# 2. more successful in __Summer Games__
# 3. more successful in __Winter Games__
#
#
# What could be the reasons?

# %%
top_50 = gender_season.head(50)

# %%
top_50
# Out:
#                          Summer  Winter   Men  Women  Total
# Country
# United States              4585     653  3618   1620   5238
# Soviet Union               2049     440  1807    682   2489
# United Kingdom             1720      79  1470    329   1799
# Germany                    1305     360  1119    546   1665
# France                     1396     152  1351    197   1548
# Italy                      1296     192  1292    196   1488
# Sweden                     1044     433  1280    197   1477
# Canada                      649     625   814    460   1274
# Australia                  1189      15   704    500   1204
# Hungary                    1079      12   840    251   1091
# Russia                      768     263   566    465   1031
# Norway                      554     457   791    220   1011
# East Germany                825     162   564    423    987
# Netherlands                 851     122   574    399    973
# Finland                     456     434   771    119    890
# China                       807      82   298    591    889
# Japan                       788      63   575    276    851
# Switzerland                 380     285   567     98    665
# Romania                     640       2   307    335    642
# Korea, South                529      87   330    286    616
# West Germany                490      94   450    134    584
# Poland                      511      27   424    114    538
# Denmark                     507       5   416     96    512
# Czechoslovakia              329     158   398     89    487
# Spain                       442       2   333    111    444
# Yugoslavia                  435       7   379     63    442
# Brazil                      431       0   303    128    431
# Austria                     146     280   330     96    426
# Belgium                     411      13   403     21    424
# Cuba                        410       0   310    100    410
# Bulgaria                    333       6   216    123    339
# Unified Team                223      60   162    121    283
# Unified Team of Germany     260      21   217     64    281
# Argentina                   259       0   187     72    259
# New Zealand                 190       1   159     32    191
# India                       184       0   181      3    184
# Ukraine                     173      11    85     99    184
# Greece                      148       0   109     39    148
# Czech Republic               56      75    97     34    131
# Belarus                     113      15    59     69    128
# Jamaica                     127       0    58     69    127
# Croatia                     114      11   113     12    125
# Pakistan                    121       0   121      0    121
# Mexico                      106       0    89     17    106
# South Africa                106       0    84     22    106
# Kenya                        93       0    80     13     93
# Turkey                       86       0    77      9     86
# Nigeria                      84       0    66     18     84
# Uruguay                      76       0    76      0     76
# Iran                         61       0    61      0     61

# %%
top_50_summer = top_50.sort_values(by='Summer', ascending=False)

# %%
top_50_winter = top_50.sort_values(by='Winter', ascending=False)
top_50_winter
# Out:
#                          Summer  Winter   Men  Women  Total
# Country
# United States              4585     653  3618   1620   5238
# Canada                      649     625   814    460   1274
# Norway                      554     457   791    220   1011
# Soviet Union               2049     440  1807    682   2489
# Finland                     456     434   771    119    890
# Sweden                     1044     433  1280    197   1477
# Germany                    1305     360  1119    546   1665
# Switzerland                 380     285   567     98    665
# Austria                     146     280   330     96    426
# Russia                      768     263   566    465   1031
# Italy                      1296     192  1292    196   1488
# East Germany                825     162   564    423    987
# Czechoslovakia              329     158   398     89    487
# France                     1396     152  1351    197   1548
# Netherlands                 851     122   574    399    973
# West Germany                490      94   450    134    584
# Korea, South                529      87   330    286    616
# China                       807      82   298    591    889
# United Kingdom             1720      79  1470    329   1799
# Czech Republic               56      75    97     34    131
# Japan                       788      63   575    276    851
# Unified Team                223      60   162    121    283
# Poland                      511      27   424    114    538
# Unified Team of Germany     260      21   217     64    281
# Belarus                     113      15    59     69    128
# Australia                  1189      15   704    500   1204
# Belgium                     411      13   403     21    424
# Hungary                    1079      12   840    251   1091
# Croatia                     114      11   113     12    125
# Ukraine                     173      11    85     99    184
# Yugoslavia                  435       7   379     63    442
# Bulgaria                    333       6   216    123    339
# Denmark                     507       5   416     96    512
# Spain                       442       2   333    111    444
# Romania                     640       2   307    335    642
# New Zealand                 190       1   159     32    191
# Mexico                      106       0    89     17    106
# Uruguay                      76       0    76      0     76
# Nigeria                      84       0    66     18     84
# Turkey                       86       0    77      9     86
# Kenya                        93       0    80     13     93
# South Africa                106       0    84     22    106
# Jamaica                     127       0    58     69    127
# Pakistan                    121       0   121      0    121
# Cuba                        410       0   310    100    410
# Greece                      148       0   109     39    148
# Brazil                      431       0   303    128    431
# India                       184       0   181      3    184
# Argentina                   259       0   187     72    259
# Iran                         61       0    61      0     61

# %% [markdown]
# ## Men vs. Women - does Culture & Religion matter?

# %% [markdown]
# __Identify Countries__ where
# 1. Men and Women are __equally successful__
# 2. __Men__ are more successful
# 3. __Women__ are more successful
#
# What could be the reasons?

# %%
top_50.sort_values(by='Men', ascending=False)
# Out:
#                          Summer  Winter   Men  Women  Total
# Country
# United States              4585     653  3618   1620   5238
# Soviet Union               2049     440  1807    682   2489
# United Kingdom             1720      79  1470    329   1799
# France                     1396     152  1351    197   1548
# Italy                      1296     192  1292    196   1488
# Sweden                     1044     433  1280    197   1477
# Germany                    1305     360  1119    546   1665
# Hungary                    1079      12   840    251   1091
# Canada                      649     625   814    460   1274
# Norway                      554     457   791    220   1011
# Finland                     456     434   771    119    890
# Australia                  1189      15   704    500   1204
# Japan                       788      63   575    276    851
# Netherlands                 851     122   574    399    973
# Switzerland                 380     285   567     98    665
# Russia                      768     263   566    465   1031
# East Germany                825     162   564    423    987
# West Germany                490      94   450    134    584
# Poland                      511      27   424    114    538
# Denmark                     507       5   416     96    512
# Belgium                     411      13   403     21    424
# Czechoslovakia              329     158   398     89    487
# Yugoslavia                  435       7   379     63    442
# Spain                       442       2   333    111    444
# Korea, South                529      87   330    286    616
# Austria                     146     280   330     96    426
# Cuba                        410       0   310    100    410
# Romania                     640       2   307    335    642
# Brazil                      431       0   303    128    431
# China                       807      82   298    591    889
# Unified Team of Germany     260      21   217     64    281
# Bulgaria                    333       6   216    123    339
# Argentina                   259       0   187     72    259
# India                       184       0   181      3    184
# Unified Team                223      60   162    121    283
# New Zealand                 190       1   159     32    191
# Pakistan                    121       0   121      0    121
# Croatia                     114      11   113     12    125
# Greece                      148       0   109     39    148
# Czech Republic               56      75    97     34    131
# Mexico                      106       0    89     17    106
# Ukraine                     173      11    85     99    184
# South Africa                106       0    84     22    106
# Kenya                        93       0    80     13     93
# Turkey                       86       0    77      9     86
# Uruguay                      76       0    76      0     76
# Nigeria                      84       0    66     18     84
# Iran                         61       0    61      0     61
# Belarus                     113      15    59     69    128
# Jamaica                     127       0    58     69    127

# %%
top_50.sort_values(by='Women', ascending=False)
# Out:
#                          Summer  Winter   Men  Women  Total
# Country
# United States              4585     653  3618   1620   5238
# Soviet Union               2049     440  1807    682   2489
# China                       807      82   298    591    889
# Germany                    1305     360  1119    546   1665
# Australia                  1189      15   704    500   1204
# Russia                      768     263   566    465   1031
# Canada                      649     625   814    460   1274
# East Germany                825     162   564    423    987
# Netherlands                 851     122   574    399    973
# Romania                     640       2   307    335    642
# United Kingdom             1720      79  1470    329   1799
# Korea, South                529      87   330    286    616
# Japan                       788      63   575    276    851
# Hungary                    1079      12   840    251   1091
# Norway                      554     457   791    220   1011
# France                     1396     152  1351    197   1548
# Sweden                     1044     433  1280    197   1477
# Italy                      1296     192  1292    196   1488
# West Germany                490      94   450    134    584
# Brazil                      431       0   303    128    431
# Bulgaria                    333       6   216    123    339
# Unified Team                223      60   162    121    283
# Finland                     456     434   771    119    890
# Poland                      511      27   424    114    538
# Spain                       442       2   333    111    444
# Cuba                        410       0   310    100    410
# Ukraine                     173      11    85     99    184
# Switzerland                 380     285   567     98    665
# Austria                     146     280   330     96    426
# Denmark                     507       5   416     96    512
# Czechoslovakia              329     158   398     89    487
# Argentina                   259       0   187     72    259
# Jamaica                     127       0    58     69    127
# Belarus                     113      15    59     69    128
# Unified Team of Germany     260      21   217     64    281
# Yugoslavia                  435       7   379     63    442
# Greece                      148       0   109     39    148
# Czech Republic               56      75    97     34    131
# New Zealand                 190       1   159     32    191
# South Africa                106       0    84     22    106
# Belgium                     411      13   403     21    424
# Nigeria                      84       0    66     18     84
# Mexico                      106       0    89     17    106
# Kenya                        93       0    80     13     93
# Croatia                     114      11   113     12    125
# Turkey                       86       0    77      9     86
# India                       184       0   181      3    184
# Pakistan                    121       0   121      0    121
# Uruguay                      76       0    76      0     76
# Iran                         61       0    61      0     61

# %%
top_50.Women.sub(top_50.Men).sort_values()
# Out:
# Country
# United States             -1998
# France                    -1154
# United Kingdom            -1141
# Soviet Union              -1125
# Italy                     -1096
# Sweden                    -1083
# Finland                    -652
# Hungary                    -589
# Germany                    -573
# Norway                     -571
# Switzerland                -469
# Belgium                    -382
# Canada                     -354
# Denmark                    -320
# Yugoslavia                 -316
# West Germany               -316
# Poland                     -310
# Czechoslovakia             -309
# Japan                      -299
# Austria                    -234
# Spain                      -222
# Cuba                       -210
# Australia                  -204
# India                      -178
# Netherlands                -175
# Brazil                     -175
# Unified Team of Germany    -153
# East Germany               -141
# New Zealand                -127
# Pakistan                   -121
# Argentina                  -115
# Croatia                    -101
# Russia                     -101
# Bulgaria                    -93
# Uruguay                     -76
# Mexico                      -72
# Greece                      -70
# Turkey                      -68
# Kenya                       -67
# Czech Republic              -63
# South Africa                -62
# Iran                        -61
# Nigeria                     -48
# Korea, South                -44
# Unified Team                -41
# Belarus                      10
# Jamaica                      11
# Ukraine                      14
# Romania                      28
# China                       293
# dtype: int64

# %% [markdown]
# ## Do Traditions matter?

# %% [markdown]
# Create the following __Seaborn Heatmap__ that shows the __Ranks__ of Top 50 Countries __by Sports__. <br>
# Identify traditional Sports / National Sports for e.g. UK and China!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
olympics
# Out:
#        index  Year    City  ... Edition         Country        Games
# 0          0  1896  Athens  ...  Summer         Hungary  1896 Athens
# 1          1  1896  Athens  ...  Summer         Austria  1896 Athens
# 2          2  1896  Athens  ...  Summer          Greece  1896 Athens
# 3          3  1896  Athens  ...  Summer          Greece  1896 Athens
# 4          4  1896  Athens  ...  Summer          Greece  1896 Athens
# ...      ...   ...     ...  ...     ...             ...          ...
# 36926  36930  2014   Sochi  ...  Winter  United Kingdom   2014 Sochi
# 36927  36931  2014   Sochi  ...  Winter   United States   2014 Sochi
# 36928  36932  2014   Sochi  ...  Winter          Canada   2014 Sochi
# 36929  36933  2014   Sochi  ...  Winter  Czech Republic   2014 Sochi
# 36930  36934  2014   Sochi  ...  Winter          France   2014 Sochi
#
# [36931 rows x 13 columns]

# %%
country = pd.crosstab(olympics.Country, olympics.Discipline).sort_values(by='Country', ascending = True)

# %%
country['Total'] = country.sum(axis=1)

# %%
country.sort_values(by='Total', ascending=False, inplace=True)

# %%
country = country.head(50).drop(columns = 'Total')
country
# Out:
# Discipline               Alpine Skiing  ...  Wrestling Gre-R
# Country                                 ...
# United States                       44  ...               15
# Soviet Union                         1  ...               60
# United Kingdom                       0  ...                0
# Germany                             22  ...               19
# France                              45  ...                7
# Italy                               30  ...               19
# Sweden                              16  ...               56
# Canada                              11  ...                0
# Australia                            1  ...                0
# Hungary                              0  ...               37
# Russia                               1  ...               15
# Norway                              29  ...                4
# East Germany                         0  ...                4
# Netherlands                          0  ...                0
# Finland                              1  ...               58
# China                                0  ...                4
# Japan                                1  ...               11
# Switzerland                         59  ...                1
# Romania                              0  ...               27
# Korea, South                         0  ...               14
# West Germany                        13  ...                5
# Poland                               0  ...               19
# Denmark                              0  ...                8
# Czechoslovakia                       1  ...               11
# Spain                                2  ...                0
# Yugoslavia                           2  ...               12
# Brazil                               0  ...                0
# Austria                            114  ...                1
# Belgium                              0  ...                0
# Cuba                                 0  ...               10
# Bulgaria                             0  ...               32
# Unified Team                         0  ...                9
# Unified Team of Germany              5  ...                7
# Argentina                            0  ...                0
# New Zealand                          1  ...                0
# India                                0  ...                0
# Ukraine                              0  ...                4
# Greece                               0  ...                9
# Czech Republic                       1  ...                0
# Belarus                              0  ...                6
# Jamaica                              0  ...                0
# Croatia                             10  ...                0
# Pakistan                             0  ...                0
# Mexico                               0  ...                1
# South Africa                         0  ...                0
# Kenya                                0  ...                0
# Turkey                               0  ...               21
# Nigeria                              0  ...                0
# Uruguay                              0  ...                0
# Iran                                 0  ...                2
#
# [50 rows x 80 columns]

# %%
country.rank(ascending=False)
# Out:
# Discipline               Alpine Skiing  ...  Wrestling Gre-R
# Country                                 ...
# United States                      4.0  ...             11.5
# Soviet Union                      18.5  ...              1.0
# United Kingdom                    36.5  ...             41.5
# Germany                            7.0  ...              9.0
# France                             3.0  ...             21.5
# Italy                              5.0  ...              9.0
# Sweden                             8.0  ...              3.0
# Canada                            10.0  ...             41.5
# Australia                         18.5  ...             41.5
# Hungary                           36.5  ...              4.0
# Russia                            18.5  ...             11.5
# Norway                             6.0  ...             26.5
# East Germany                      36.5  ...             26.5
# Netherlands                       36.5  ...             41.5
# Finland                           18.5  ...              2.0
# China                             36.5  ...             26.5
# Japan                             18.5  ...             15.5
# Switzerland                        2.0  ...             31.0
# Romania                           36.5  ...              6.0
# Korea, South                      36.5  ...             13.0
# West Germany                       9.0  ...             24.0
# Poland                            36.5  ...              9.0
# Denmark                           36.5  ...             20.0
# Czechoslovakia                    18.5  ...             15.5
# Spain                             13.5  ...             41.5
# Yugoslavia                        13.5  ...             14.0
# Brazil                            36.5  ...             41.5
# Austria                            1.0  ...             31.0
# Belgium                           36.5  ...             41.5
# Cuba                              36.5  ...             17.0
# Bulgaria                          36.5  ...              5.0
# Unified Team                      36.5  ...             18.5
# Unified Team of Germany           12.0  ...             21.5
# Argentina                         36.5  ...             41.5
# New Zealand                       18.5  ...             41.5
# India                             36.5  ...             41.5
# Ukraine                           36.5  ...             26.5
# Greece                            36.5  ...             18.5
# Czech Republic                    18.5  ...             41.5
# Belarus                           36.5  ...             23.0
# Jamaica                           36.5  ...             41.5
# Croatia                           11.0  ...             41.5
# Pakistan                          36.5  ...             41.5
# Mexico                            36.5  ...             31.0
# South Africa                      36.5  ...             41.5
# Kenya                             36.5  ...             41.5
# Turkey                            36.5  ...              7.0
# Nigeria                           36.5  ...             41.5
# Uruguay                           36.5  ...             41.5
# Iran                              36.5  ...             29.0
#
# [50 rows x 80 columns]

# %%
plt.figure(figsize=(50,10))
sns.heatmap(country.rank(ascending=False).head(20), cmap='RdYlGn_r', annot = True)

# %% [markdown]
# # Missing full Country Names (see Data Cleaning Part 1)

# %%
{'URS': 'Soviet Union',
 'GDR': 'East Germany',
 'ROU': 'Romania',
 'FRG': 'West Germany',
 'TCH': 'Czechoslovakia',
 'YUG': 'Yugoslavia',
 'EUN': 'Unified Team',
 'EUA': 'Unified Team of Germany',
 'ZZX': 'Mixed teams',
 'SRB': 'Serbia',
 'ANZ': 'Australasia',
 'RU1': 'Russian Empire',
 'MNE': 'Montenegro',
 'TTO': 'Trinidad and Tobago',
 'BOH': 'Bohemia',
 'BWI': 'West Indies Federation',
 'SGP': 'Singapore',
 'IOP': 'Independent Olympic Participants'}
